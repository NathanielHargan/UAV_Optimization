# %%
import matplotlib.pyplot as plt
from Scripts.drone import Drone

def plot_drone_geometry(drone_geo):
    plt.scatter(drone_geo.nodes[:,0], drone_geo.nodes[:,1])
    for beam in drone_geo.beams:
        print(beam[0])
        print(drone_geo.nodes[beam[0]])
        node_0_x = drone_geo.nodes[beam[0]][0]
        node_1_x = drone_geo.nodes[beam[1]][0]
        node_0_y = drone_geo.nodes[beam[0]][1]
        node_1_y = drone_geo.nodes[beam[1]][1]
        plt.plot([node_0_x,node_1_x],[node_0_y,node_1_y])

d1 = Drone("drone_test",20)
d1.create_drone(0.05,0.5,8)  # hub radius | nominal radius | number of blades
plot_drone_geometry(d1)s
