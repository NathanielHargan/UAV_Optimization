# %%
import math
import matplotlib.pyplot as plt
from Scripts.drone import Drone
from Scripts.beams import BeamType

def plot_drone_geometry(drone):
    drone_geo = drone.beam_system
    plt.scatter(drone_geo.nodes[:,0], drone_geo.nodes[:,1])
    for beam in drone_geo.beams:
        node_0_x = beam.start_node_coords[0]
        node_1_x = beam.end_node_coords[0]
        node_0_y = beam.start_node_coords[1]
        node_1_y = beam.end_node_coords[1]
        plt.plot([node_0_x,node_1_x],[node_0_y,node_1_y])

d1 = Drone("drone_test")
arm_beam = BeamType("annulus", [0.005, 0.0045], "Aluminum7075-T6", "arm_beam")
strut_beam = BeamType("annulus", [0.003, 0.0025], "Aluminum7075-T6", "strut_beam")

d1.create_drone_nodes(0.5,0.2,8)           # hub radius | nominal radius | number of blades
#d1.rotate_drone_nodes(0,0,math.pi/60)      # x-axis | y-axis | z-axis
d1.create_drone_beams(arm_beam,strut_beam) # arm beam | strut beam

plot_drone_geometry(d1)
# Out:
# midpoint node:  [0.35 0.   0.  ]
# start node:  outer_node_0
# mid node:  outer_mass_pnt_0
# end node:  strut_node_0
# midpoint node:  [0.1 0.  0. ]
# start node:  strut_node_0
# mid node:  inner_mass_pnt_0
# end node:  origin
# midpoint node:  [0.24748737 0.24748737 0.        ]
# start node:  outer_node_1
# mid node:  outer_mass_pnt_1
# end node:  strut_node_1
# midpoint node:  [0.07071068 0.07071068 0.        ]
# start node:  strut_node_1
# mid node:  inner_mass_pnt_1
# end node:  origin
# midpoint node:  [2.1431319e-17 3.5000000e-01 0.0000000e+00]
# start node:  outer_node_2
# mid node:  outer_mass_pnt_2
# end node:  strut_node_2
# midpoint node:  [6.123234e-18 1.000000e-01 0.000000e+00]
# start node:  strut_node_2
# mid node:  inner_mass_pnt_2
# end node:  origin
# midpoint node:  [-0.24748737  0.24748737  0.        ]
# start node:  outer_node_3
# mid node:  outer_mass_pnt_3
# end node:  strut_node_3
# midpoint node:  [-0.07071068  0.07071068  0.        ]
# start node:  strut_node_3
# mid node:  inner_mass_pnt_3
# end node:  origin
# midpoint node:  [-3.5000000e-01  4.2862638e-17  0.0000000e+00]
# start node:  outer_node_4
# mid node:  outer_mass_pnt_4
# end node:  strut_node_4
# midpoint node:  [-1.0000000e-01  1.2246468e-17  0.0000000e+00]
# start node:  strut_node_4
# mid node:  inner_mass_pnt_4
# end node:  origin
# midpoint node:  [-0.24748737 -0.24748737  0.        ]
# start node:  outer_node_5
# mid node:  outer_mass_pnt_5
# end node:  strut_node_5
# midpoint node:  [-0.07071068 -0.07071068  0.        ]
# start node:  strut_node_5
# mid node:  inner_mass_pnt_5
# end node:  origin
# midpoint node:  [-6.4293957e-17 -3.5000000e-01  0.0000000e+00]
# start node:  outer_node_6
# mid node:  outer_mass_pnt_6
# end node:  strut_node_6
# midpoint node:  [-1.8369702e-17 -1.0000000e-01  0.0000000e+00]
# start node:  strut_node_6
# mid node:  inner_mass_pnt_6
# end node:  origin
# midpoint node:  [ 0.24748737 -0.24748737  0.        ]
# start node:  outer_node_7
# mid node:  outer_mass_pnt_7
# end node:  strut_node_7
# midpoint node:  [ 0.07071068 -0.07071068  0.        ]
# start node:  strut_node_7
# mid node:  inner_mass_pnt_7
# end node:  origin
# midpoint node:  [ 0.17071068 -0.07071068  0.        ]
# start node:  strut_node_7
# mid node:  strut_mass_pnt_0
# end node:  strut_node_0
# midpoint node:  [0.17071068 0.07071068 0.        ]
# start node:  strut_node_0
# mid node:  strut_mass_pnt_1
# end node:  strut_node_1
# midpoint node:  [0.07071068 0.17071068 0.        ]
# start node:  strut_node_1
# mid node:  strut_mass_pnt_2
# end node:  strut_node_2
# midpoint node:  [-0.07071068  0.17071068  0.        ]
# start node:  strut_node_2
# mid node:  strut_mass_pnt_3
# end node:  strut_node_3
# midpoint node:  [-0.17071068  0.07071068  0.        ]
# start node:  strut_node_3
# mid node:  strut_mass_pnt_4
# end node:  strut_node_4
# midpoint node:  [-0.17071068 -0.07071068  0.        ]
# start node:  strut_node_4
# mid node:  strut_mass_pnt_5
# end node:  strut_node_5
# midpoint node:  [-0.07071068 -0.17071068  0.        ]
# start node:  strut_node_5
# mid node:  strut_mass_pnt_6
# end node:  strut_node_6
# midpoint node:  [ 0.07071068 -0.17071068  0.        ]
# start node:  strut_node_6
# mid node:  strut_mass_pnt_7
# end node:  strut_node_7
