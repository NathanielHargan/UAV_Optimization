# %%
k = 500
a_e = 4
a_u = 10

def f_inclass(a):
    return 7 * a ** 2 - 20 * a + 22

for i in range(k):
    I = a_u - a_e
    fa_e = f_inclass(a_e)
    fa_u = f_inclass(a_u)
    a_a = a_e + I*(1/3)
    a_b = a_e + I*(2/3)
    fa_a = f_inclass(a_a)
    fa_b = f_inclass(a_b)
    if fa_a < fa_b:
        a_u = a_b
    else:
        a_e = a_a

print("a_e: ", a_e)
print("a_u: ",a_u)
# Out:
# a_e:  6.000000000000002
# a_u:  6.000000000000003

# %% [markdown]
# # quadprog please use for sqp sub problem
#
# # SQP algoritm
#
# # Step 1:
#
# # initial guess
#
# xi = 0
# k = 0
# e1 = 0.0005
# e2 = 0.0005
# ''''''
# Develop the qp subproblem
# (dk var)
#
# solve the QP subproblem ( use quadprog) (or KKT, Gradient based , into point,...)
#
# Find the step size ak
# develop ascent function (need gradient)
#
# apply anlytic num methods to solve for ak
#
# Check for convergence:
# if dk <= e1
# if gi <= e2
# ifhj <= e2
# 3 criteria sets
# checking all the constraints
#
# otherwise continue.
#
# update the design point:
