# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from Scripts.drone import Drone
from Scripts.beams import BeamType

def plot_drone_geometry(drone):
    drone_geo = drone.beam_system
    plt.scatter(drone_geo.nodes[:,0], drone_geo.nodes[:,1])
    for beam in drone_geo.beams:
        node_0_x = beam.start_node_coords[0]
        node_1_x = beam.end_node_coords[0]
        node_0_y = beam.start_node_coords[1]
        node_1_y = beam.end_node_coords[1]
        plt.plot([node_0_x,node_1_x],[node_0_y,node_1_y])

d1 = Drone("drone_test")
arm_beam = BeamType("annulus", [5, 4], "Aluminum7075-T6", "arm_beam")
strut_beam = BeamType("annulus", [3, 2], "Aluminum7075-T6", "strut_beam")



d1.create_drone_nodes(0.5,0.2,8)           # hub radius | nominal radius | number of blades
#d1.rotate_drone_nodes(0,0,math.pi/60)      # x-axis | y-axis | z-axis
d1.create_drone_beams(arm_beam,strut_beam) # arm beam | strut beam
plot_drone_geometry(d1)
d1.boundary_conditions()
d1.solve_fea()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 23
#      18 arm_beam = BeamType("annulus", [5, 4], "Aluminum7075-T6", "arm_beam")
#      19 strut_beam = BeamType("annulus", [3, 2], "Aluminum7075-T6", "strut_beam")
# ---> 23 d1.create_drone_nodes(0.5,0.2,8)           # hub radius | nominal radius | number of blades
#      24 #d1.rotate_drone_nodes(0,0,math.pi/60)      # x-axis | y-axis | z-axis
#      25 d1.create_drone_beams(arm_beam,strut_beam) # arm beam | strut beam
#
# File C:\Desktop\UAV_Mission\Scripts\drone.py:87, in Drone.create_drone_nodes(self, nominal_rad, strut_pos, blade_num)
#      84 num = 0
#      86 # Origin
# ---> 87 self.beam_system.add_node(
#      88     0,
#      89     0,
#      90     0,
#      91     'origin')
#      93 # Rotational Symmetry Nodes
#      94 for theta in np.linspace(0, 2*math.pi*(blade_num-1)/blade_num, num=blade_num):
#      95     # Adds the node where the blades are
#
# TypeError: BeamSystem.add_node() takes from 2 to 3 positional arguments but 5 were given

# %%
plt.imshow(np.where(d1.beam_system.global_stiffness_matrix == 0, 0, 1), interpolation='none', cmap='gray')
plt.title('k before partition')
# Out:
# Text(0.5, 1.0, 'k before partition')
